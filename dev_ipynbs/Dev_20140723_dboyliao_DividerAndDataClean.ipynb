# %%
import pandas as pd
import numpy as np

# %%
## Data Slicer.
def data_slicer(file_path, bytes_max):
    data_file = open(file_path)
    colnames = data_file.readline()
    colnames = colnames.strip().split(',')
    lines = [line.strip().split(',') for line in data_file.readlines(bytes_max)]
    count = 1
    file_prefix = file_path[:-4]
    while lines != []:
        file_name = file_prefix + '_split' + '%.4d' % count +'.csv'
        print "Processing " + file_name
        data = pd.DataFrame(lines, columns = colnames)
        data.to_csv(file_name, sep = ',', encoding = 'utf-8')
        lines = [line.strip().split(',') for line in data_file.readlines(bytes_max)]
        count += 1

# %%
f = open('/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train.csv')

# %%
colnames = f.readline()
colnames = colnames.strip().split(',')
print colnames
# Out:
# ['Id', 'Label', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10', 'I11', 'I12', 'I13', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21', 'C22', 'C23', 'C24', 'C25', 'C26']

# %%
# 300000000 is about 12 millions observations.
lines = [line.strip().split(',') for line in f.readlines(10000000)]

# %%
df = pd.DataFrame(lines, columns=colnames)

# %%
df
# Out:
#              Id Label   I1   I2   I3  I4      I5   I6   I7  I8 ...       C17  \
# 0      10000000     0    1    1    5   0    1382    4   15   2 ...  e5ba7672
# 1      10000001     0    2    0   44   1     102    8    2   2 ...  07c540c4
# 2      10000002     0    2    0    1  14     767   89    4   2 ...  8efede7f
# 3      10000003     0       893             4392         0   0 ...  1e88c74f
# 4      10000004     0    3   -1        0       2    0    3   0 ...  1e88c74f
# 5      10000005     0        -1            12824         0   0 ...  776ce399
# 6      10000006     0         1    2        3168         0   1 ...  776ce399
# 7      10000007     1    1    4    2   0       0    0    1   0 ...  e5ba7672
# 8      10000008     0        44    4   8   19010  249   28  31 ...  e5ba7672
# 9      10000009     0        35        1   33737   21    1   2 ...  d4bb7bd8
# 10     10000010     0         2  632   0   56770         0   5 ...  776ce399
# ...

# %%
f.close()

# %%
# Slicing Big data into smaller subdata files.

file_path = '/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train.csv'
data_slicer(file_path, 250000000)
# Out:
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0001.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0002.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0003.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0004.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0005.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0006.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0007.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0008.csv
# Processing /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0009.csv
# ...

# %%
# Data Cleaning.
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
def data_clean(input_path, output_path, C_cols, id_index = None, nan_rm = False, result = False):
    print 'Reading ' + input_path
    data = pd.DataFrame.from_csv(input_path)
    if id_index != None:
        print 'Setting row names into columne %.20s.' % id_index
        data = data.set_index(id_index)
    print "Factorizing categorical columns."
    for col in C_cols:
        le = preprocessing.LabelEncoder()
        data[col].values.astype('a8')
        le.fit(data[col])
        data[col] = le.transform(data[col].values)
    if nan_rm:
        print 'Removing NaN observations'
        for col in data.columns:
            data = data[np.isfinite(data[col])]
    print "Output " + output_path
    data.to_csv(output_path)
    if result:
        return data

# %%
file_path = "/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/"
count = 1
file_prefix = 'train_split'
file_formate = '.csv'

file_name = file_path + file_prefix + "%.4d" % count + '.csv'
C_cols = ['C' + str(ind) for ind in range(1, 27)]
output_path = file_path + 'clean_' + file_prefix + "%.4d" % count + ".csv"
data = data_clean(file_name, output_path, C_cols, nan_rm = True, result = True)
for count in range(2, 48):
    output_path = file_path + 'clean_' + file_prefix + "%.4d" % count + ".csv"
    file_name = file_path + file_prefix + "%.4d" % count + '.csv'
    data_tmp = data_clean(file_name, output_path, C_cols, nan_rm = True ,result = True)
    data = pd.concat([data, data_tmp])
# Out:
# Reading /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0001.csv
# Factorizing categorical columns.
# Removing NaN observations
# Output /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/clean_train_split0001.csv
# Reading /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0002.csv
# Factorizing categorical columns.
# Removing NaN observations
# Output /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/clean_train_split0002.csv
# Reading /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0003.csv
# Factorizing categorical columns.
# Removing NaN observations
# Output /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/clean_train_split0003.csv
# Reading /Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/train_split0004.csv
# Factorizing categorical columns.
# Removing NaN observations
# ...

# %%
data.to_csv("/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/complete_train.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6a1a848d8469> in <module>()
# ----> 1 data.to_csv("/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/complete_train.csv")
#
# NameError: name 'data' is not defined

# %%
## Data imputer
data = pd.DataFrame.from_csv("/Users/DboyLiao/Documents/kaggle/data/Display_Advertising_Challenge/complete_train.csv")

# %%
data = data.set_index('Id')
X = data.drop('Label', 1)
data
# Out:
#           Label  I1    I2   I3  I4     I5    I6   I7  I8    I9  ...   C17  \
# Id                                                              ...
# 10000002      0   2     0    1  14    767    89    4   2   245  ...     6
# 10000026      1   0     1   20  16   1548    93   42  32   912  ...     3
# 10000027      1   0    20    2   2   7188   170    2   3    24  ...     4
# 10000035      1   0   127    1   3   1683    19   26  17   475  ...     6
# 10000048      0   1  2382   13   4     40     4   69   3   609  ...     9
# 10000053      0   0     2   22   3   4687   242    6   6   183  ...     6
# 10000056      0   0    19    9   3  14414  1353    3   1   362  ...     6
# 10000064      0   1     1    5   8      7     8    1   8     8  ...     8
# 10000078      1   2     1   60  75     61   121   52  39   248  ...     6
# 10000079      0   1    34    2  42    328    44   15  49    58  ...     9
# 10000103      1   0    30    2  25   2204   182   62  33  1127  ...     4
# ...

# %%
X.columns
# Out:
# Index([u'I1', u'I2', u'I3', u'I4', u'I5', u'I6', u'I7', u'I8', u'I9', u'I10', u'I11', u'I12', u'I13', u'C1', u'C2', u'C3', u'C4', u'C5', u'C6', u'C7', u'C8', u'C9', u'C10', u'C11', u'C12', u'C13', u'C14', u'C15', u'C16', u'C17', u'C18', u'C19', u'C20', u'C21', u'C22', u'C23', u'C24', u'C25', u'C26'], dtype='object')

# %%
def imputers_train(data, col_classes):
    # Initializing an empty list to store the imputers
    imputers = []
    for col_ind in range(len(col_classes)):
        col = data.columns[col_ind]
        print "Processing the imputer of column " + col + "."
        col_class = col_classes[col_ind]
        Y = data[col]
        X = data.drop(col, 1)
        if col_class == 'categorical':
            rfc = RFC(n_estimators=20)
            imputer = rfc.fit(X, Y)
            imputers.append(imputer)
        elif col_class == 'numeric':
            rfr = RFR(n_estimators=20)
            imputer = rfr.fit(X, Y)
            imputers.append(imputer)
        else:
            pass
    return imputers

# %%
col_classes = ["numeric" if ind <= 12 else "categorical" for ind in range(39)]
print "col_classes\n", col_classes
# Out:
# col_classes
# ['numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'numeric', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical']

# %%
imputers = imputers_train(X, col_classes)
